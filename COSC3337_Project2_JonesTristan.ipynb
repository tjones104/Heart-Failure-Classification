# %% [markdown]
# #### Tristan Jones
# #### PS:1486089
# #### Group Project Classification: Part 1

# %% [markdown]
# # Preprocessing

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
address = 'C:/Users/Tristan/Desktop/Data Science 3337/Projects/Project 2/heart_failure.csv'
df = pd.read_csv(address)
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
df.shape
# Out:
# (299, 13)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Checking and storing column names

# %%
col_names = df.columns
col_names
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %% [markdown]
# ## Checking datatypes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %% [markdown]
# ## Checking for missing values

# %%
df.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %% [markdown]
# ## Creating Train and Test set

# %%
X = df.drop(['DEATH_EVENT'], axis=1)
y = df['DEATH_EVENT']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 123)

# %% [markdown]
# ## Counting Bins

# %%
np.bincount(y)
# Out:
# array([203,  96], dtype=int64)

# %%
np.bincount(y_train)
# Out:
# array([150,  59], dtype=int64)

# %%
np.bincount(y_test)
# Out:
# array([53, 37], dtype=int64)

# %%
plt.figure(figsize=(30,30))
df0 = df['age'][(df[['DEATH_EVENT']] == 0).all(1)]
df1 = df['age'][(df[['DEATH_EVENT']] == 1).all(1)]
plt.subplot(4, 2, 1)
fig = df0.hist(bins=50)
fig = df1.hist(bins=50)
plt.legend('01')
fig.set_xlabel('Age')
fig.set_ylabel('Frequency')
fig.set_title("Age Frequency Per Class")
# Out:
# Text(0.5, 1.0, 'Age Frequency Per Class')

# %%
plt.figure(figsize=(30,30))
df0 = df['anaemia'][(df[['DEATH_EVENT']] == 0).all(1)]
df1 = df['anaemia'][(df[['DEATH_EVENT']] == 1).all(1)]
plt.subplot(4, 2, 1)
fig = df0.hist(bins=3)
fig = df1.hist(bins=3)
plt.legend('01')
plt.xlim([0, 1.1])
fig.set_xlabel('Anaemia')
fig.set_ylabel('Frequency')
fig.set_title("Anaemia Frequency Per Class")
# Out:
# Text(0.5, 1.0, 'Anaemia Frequency Per Class')

# %%
plt.figure(figsize=(30,30))
df0 = df['creatinine_phosphokinase'][(df[['DEATH_EVENT']] == 0).all(1)]
df1 = df['creatinine_phosphokinase'][(df[['DEATH_EVENT']] == 1).all(1)]
plt.subplot(4, 2, 1)
fig = df0.hist(bins=50)
fig = df1.hist(bins=50)
plt.legend('01')
fig.set_xlabel('Creatinine Phosphokinase')
fig.set_ylabel('Frequency')
fig.set_title("Creatinine Phosphokinase Frequency Per Class")
# Out:
# Text(0.5, 1.0, 'Creatinine Phosphokinase Frequency Per Class')

# %%
plt.figure(figsize=(30,30))
df0 = df['diabetes'][(df[['DEATH_EVENT']] == 0).all(1)]
df1 = df['diabetes'][(df[['DEATH_EVENT']] == 1).all(1)]
plt.subplot(4, 2, 1)
fig = df0.hist(bins=3)
fig = df1.hist(bins=3)
plt.legend('01')
plt.xlim([0, 1.1])
fig.set_xlabel('Diabetes')
fig.set_ylabel('Frequency')
fig.set_title("Diabetes Frequency Per Class")
# Out:
# Text(0.5, 1.0, 'Diabetes Frequency Per Class')

# %%
plt.figure(figsize=(30,30))
df0 = df['ejection_fraction'][(df[['DEATH_EVENT']] == 0).all(1)]
df1 = df['ejection_fraction'][(df[['DEATH_EVENT']] == 1).all(1)]
plt.subplot(4, 2, 1)
fig = df0.hist(bins=50)
fig = df1.hist(bins=50)
plt.legend('01')
fig.set_xlabel('Ejection Fraction')
fig.set_ylabel('Frequency')
fig.set_title("Ejection Fraction Frequency Per Class")
# Out:
# Text(0.5, 1.0, 'Ejection Fraction Frequency Per Class')

# %%
plt.figure(figsize=(30,30))
df0 = df['high_blood_pressure'][(df[['DEATH_EVENT']] == 0).all(1)]
df1 = df['high_blood_pressure'][(df[['DEATH_EVENT']] == 1).all(1)]
plt.subplot(4, 2, 1)
fig = df0.hist(bins=3)
fig = df1.hist(bins=3)
plt.legend('01')
plt.xlim([0, 1.1])
fig.set_xlabel('High Blood Pressure')
fig.set_ylabel('Frequency')
fig.set_title("High Blood Pressure Frequency Per Class")
# Out:
# Text(0.5, 1.0, 'High Blood Pressure Frequency Per Class')

# %%
plt.figure(figsize=(30,30))
df0 = df['platelets'][(df[['DEATH_EVENT']] == 0).all(1)]
df1 = df['platelets'][(df[['DEATH_EVENT']] == 1).all(1)]
plt.subplot(4, 2, 1)
fig = df0.hist(bins=50)
fig = df1.hist(bins=50)
plt.legend('01')
fig.set_xlabel('platelets')
fig.set_ylabel('Frequency')
fig.set_title("platelets Frequency Per Class")
# Out:
# Text(0.5, 1.0, 'platelets Frequency Per Class')

# %%
plt.figure(figsize=(30,30))
df0 = df['serum_creatinine'][(df[['DEATH_EVENT']] == 0).all(1)]
df1 = df['serum_creatinine'][(df[['DEATH_EVENT']] == 1).all(1)]
plt.subplot(4, 2, 1)
fig = df0.hist(bins=50)
fig = df1.hist(bins=50)
plt.legend('01')
fig.set_xlabel('Serum Creatinine')
fig.set_ylabel('Frequency')
fig.set_title("Serum Creatinine Frequency Per Class")
# Out:
# Text(0.5, 1.0, 'Serum Creatinine Frequency Per Class')

# %%
plt.figure(figsize=(30,30))
df0 = df['serum_sodium'][(df[['DEATH_EVENT']] == 0).all(1)]
df1 = df['serum_sodium'][(df[['DEATH_EVENT']] == 1).all(1)]
plt.subplot(4, 2, 1)
fig = df0.hist(bins=50)
fig = df1.hist(bins=50)
plt.legend('01')
fig.set_xlabel('Serum Sodium')
fig.set_ylabel('Frequency')
fig.set_title("Serum Sodium Frequency Per Class")
# Out:
# Text(0.5, 1.0, 'Serum Sodium Frequency Per Class')

# %%
plt.figure(figsize=(30,30))
df0 = df['sex'][(df[['DEATH_EVENT']] == 0).all(1)]
df1 = df['sex'][(df[['DEATH_EVENT']] == 1).all(1)]
plt.subplot(4, 2, 1)
fig = df0.hist(bins=3)
fig = df1.hist(bins=3)
plt.legend('01')
plt.xlim([0, 1.1])
fig.set_xlabel('Sex')
fig.set_ylabel('Frequency')
fig.set_title("Sex Frequency Per Class")
# Out:
# Text(0.5, 1.0, 'Sex Frequency Per Class')

# %%
plt.figure(figsize=(30,30))
df0 = df['smoking'][(df[['DEATH_EVENT']] == 0).all(1)]
df1 = df['smoking'][(df[['DEATH_EVENT']] == 1).all(1)]
plt.subplot(4, 2, 1)
fig = df0.hist(bins=3)
fig = df1.hist(bins=3)
plt.legend('01')
plt.xlim([0, 1.1])
fig.set_xlabel('Smoking')
fig.set_ylabel('Frequency')
fig.set_title("Smoking Frequency Per Class")
# Out:
# Text(0.5, 1.0, 'Smoking Frequency Per Class')
